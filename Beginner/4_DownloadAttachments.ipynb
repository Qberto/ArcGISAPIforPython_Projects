# %% [markdown]
# ### Connect to GIS

# %%
import arcgis
from IPython.display import display
import getpass
import os

# %%
portals_dict = {
    "esrifederal_gis": r"https://esrifederal.maps.arcgis.com",
    "natgov_gis": r"http://esri-natgov105.eastus.cloudapp.azure.com/arcgis",
    "dot_gis": r"http://dot.esri.com/portal",
    "dev_gis": r"http://govdev.eastus.cloudapp.azure.com/arcgis",
    "local_gis": r"https://anieto.esri.com/arcgis"
}

# %%
gis_url = portals_dict["esrifederal_gis"]

# %%
if gis_url == portals_dict["esrifederal_gis"]:
    gis_app_id = r"wt3QUR1M4eum0TVI"
    print("Attempting to log in to '{0}'...".format(gis_url))
    gis = arcgis.gis.GIS(gis_url, client_id=gis_app_id)
    print("Successfully logged in as: " + gis.properties.user.username)
else:
    gis_username = getpass.getpass(prompt="Username: ")
    gis_pw = getpass.getpass(prompt="Password: ")
    print("Attempting to log in to '{0}'...".format(gis_url))
    gis = arcgis.gis.GIS(gis_url, gis_username, gis_pw, verify_cert=False)
    print("Successfully logged in as: " + gis.properties.user.username)
# Out:
# Attempting to log in to 'https://esrifederal.maps.arcgis.com'...
# Please sign in to your GIS and paste the code that is obtained below.
# If a web browser does not automatically open, please navigate to the URL below yourself instead.
# Opening web browser to navigate to: https://esrifederal.maps.arcgis.com/sharing/rest/oauth2/authorize?client_id=wt3QUR1M4eum0TVI&expiration=-1&response_type=code&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob
# Enter code obtained on signing in using SAML: ········
# Successfully logged in as: albe9057@esri.com_esrifederal

# %%
gis.map()

# %% [markdown]
# ### Retrieve photos from Hurricane Irma attachment layer

# %%
photos_lyr_rest_url = r"https://services.arcgis.com/0ZRg6WRC7mxSLyKX/arcgis/rest/services/hurricaneIrmaPhotoStoryMap/FeatureServer/0"

photos_layer = arcgis.features.FeatureLayer(photos_lyr_rest_url)
photos_layer
# Out:
# <FeatureLayer url:"https://services.arcgis.com/0ZRg6WRC7mxSLyKX/arcgis/rest/services/hurricaneIrmaPhotoStoryMap/FeatureServer/0">

# %%
photos_layer.properties
# Out:
# {
#   "standardMaxRecordCount": 32000,
#   "relationships": [],
#   "editFieldsInfo": {
#     "creatorField": "Creator",
#     "editDateField": "EditDate",
#     "creationDateField": "CreationDate",
#     "editorField": "Editor"
#   },
#   "allowGeometryUpdates": true,
#   "isDataVersioned": false,
#   "fields": [
#     {
#       "nullable": false,
#       "actualType": "int",
#       "name": "FID",
#       "alias": "Feature ID",
#       "sqlType": "sqlTypeInteger",
#       "type": "esriFieldTypeInteger",
#       "editable": false,
#       "defaultValue": null,
#       "domain": null
#     },
#     {
#       "nullable": false,
#       "name": "GlobalID",
#       "alias": "GlobalID",
#       "sqlType": "sqlTypeOther",
#       "type": "esriFieldTypeGlobalID",
#       "domain": null,
#       "editable": false,
#       "defaultValue": "NEWID() WITH VALUES",
#       "length": 38
#     },
#     {
#       "nullable": true,
#       "name": "CreationDate",
#       "alias": "CreationDate",
#       "sqlType": "sqlTypeOther",
#       "type": "esriFieldTypeDate",
#       "domain": null,
#       "editable": false,
#       "defaultValue": null,
#       "length": 8
#     },
#     {
#       "nullable": true,
#       "name": "Creator",
#       "alias": "Creator",
#       "sqlType": "sqlTypeOther",
#       "type": "esriFieldTypeString",
#       "domain": null,
#       "editable": false,
#       "defaultValue": null,
#       "length": 50
#     },
#     {
#       "nullable": true,
#       "name": "EditDate",
#       "alias": "EditDate",
#       "sqlType": "sqlTypeOther",
#       "type": "esriFieldTypeDate",
#       "domain": null,
#       "editable": false,
#       "defaultValue": null,
#       "length": 8
#     },
#     {
#       "nullable": true,
#       "name": "Editor",
#       "alias": "Editor",
#       "sqlType": "sqlTypeOther",
#       "type": "esriFieldTypeString",
#       "domain": null,
#       "editable": false,
#       "defaultValue": null,
#       "length": 50
#     },
#     {
#       "nullable": true,
#       "name": "Name",
#       "alias": "Name",
#       "sqlType": "sqlTypeOther",
#       "type": "esriFieldTypeString",
#       "domain": null,
#       "editable": true,
#       "defaultValue": null,
#       "length": 256
#     },
#     {
#       "nullable": true,
#       "name": "Description",
#       "alias": "Description",
#       "sqlType": "sqlTypeOther",
#       "type": "esriFieldTypeString",
#       "domain": null,
#       "editable": true,
#       "defaultValue": null,
#       "length": 1500
#     },
#     {
#       "nullable": true,
#       "name": "LocationName",
#       "alias": "Location Name",
#       "sqlType": "sqlTypeOther",
#       "type": "esriFieldTypeString",
#       "domain": null,
#       "editable": true,
#       "defaultValue": null,
#       "length": 256
#     },
#     {
#       "nullable": true,
#       "name": "Hidden",
#       "alias": "Share Hidden",
#       "sqlType": "sqlTypeOther",
#       "type": "esriFieldTypeInteger",
#       "editable": true,
#       "defaultValue": null,
#       "domain": null
#     },
#     {
#       "nullable": true,
#       "name": "Vetted",
#       "alias": "Share Vetted",
#       "sqlType": "sqlTypeOther",
#       "type": "esriFieldTypeInteger",
#       "editable": true,
#       "defaultValue": null,
#       "domain": null
#     }
#   ],
#   "editingInfo": {
#     "lastEditDate": 1505602124612
#   },
#   "supportsAttachmentsByUploadId": true,
#   "objectIdField": "FID",
#   "supportsApplyEditsWithGlobalIds": true,
#   "serviceItemId": "b5d3f5803d7f4ba9ab7c3bd7b2ef2de6",
#   "description": "",
#   "type": "Feature Layer",
#   "copyrightText": "",
#   "extent": {
#     "spatialReference": {
#       "latestWkid": 3857,
#       "wkid": 102100
#     },
#     "xmin": -20085668.703089,
#     "ymin": -20085668.703089,
#     "xmax": 20085668.703089,
#     "ymax": 20085668.703089
#   },
#   "supportsCalculate": true,
#   "hasZ": false,
#   "indexes": [
#     {
#       "isUnique": false,
#       "name": "CreationDateIndex",
#       "fields": "CreationDate",
#       "isAscending": true,
#       "description": "CreationDate Field index"
#     },
#     {
#       "isUnique": false,
#       "name": "CreatorIndex",
#       "fields": "Creator",
#       "isAscending": false,
#       "description": "Creator Field index"
#     },
#     {
#       "isUnique": false,
#       "name": "EditDateIndex",
#       "fields": "EditDate",
#       "isAscending": true,
#       "description": "EditDate Field index"
#     },
#     {
#       "isUnique": false,
#       "name": "EditorIndex",
#       "fields": "Editor",
#       "isAscending": false,
#       "description": "Editor Field index"
#     },
#     {
#       "isUnique": false,
#       "name": "user_3248.hurricaneIrmaPhotoStoryMap_CROWDSOURCEFEATURES_Shape_sidx",
#       "fields": "Shape",
#       "isAscending": false,
#       "description": "Shape Index"
#     },
#     {
#       "isUnique": true,
#       "name": "PK__hurrican__C1BEA5A2F8A1B236",
#       "fields": "FID",
#       "isAscending": true,
#       "description": "clustered, unique, primary key"
#     }
#   ],
#   "supportsStatistics": true,
#   "globalIdField": "GlobalID",
#   "useStandardizedQueries": false,
#   "advancedQueryCapabilities": {
#     "supportsPaginationOnAggregatedQueries": true,
#     "supportsSqlExpression": true,
#     "supportsQueryWithDistance": true,
#     "supportsStatistics": true,
#     "supportsQueryAttachments": true,
#     "supportsAdvancedQueryRelated": true,
#     "supportsQueryWithResultType": true,
#     "supportsPagination": true,
#     "supportsOrderBy": true,
#     "supportsReturningQueryExtent": true,
#     "supportsQueryWithDatumTransformation": true,
#     "supportsDistinct": true,
#     "supportsQueryRelatedPagination": true,
#     "supportsReturningGeometryCentroid": false
#   },
#   "templates": [
#     {
#       "drawingTool": "esriFeatureEditToolPoint",
#       "name": "New Feature",
#       "description": "",
#       "prototype": {
#         "attributes": {
#           "LocationName": null,
#           "Vetted": null,
#           "Name": null,
#           "Description": null,
#           "Hidden": null
#         }
#       }
#     }
#   ],
#   "name": "crowdsourceFeatures",
#   "supportsCoordinatesQuantization": true,
#   "types": [],
#   "supportsRollbackOnFailureParameter": true,
#   "hasM": false,
#   "supportsAdvancedQueries": true,
#   "minScale": 0,
#   "currentVersion": 10.51,
#   "supportedQueryFormats": "JSON, geoJSON",
#   "maxRecordCount": 2000,
#   "defaultVisibility": true,
#   "typeIdField": "",
#   "maxScale": 0,
#   "hasAttachments": true,
#   "maxRecordCountFactor": 1,
#   "tileMaxRecordCount": 8000,
#   "displayField": "",
#   "attachmentProperties": [
#     {
#       "name": "name",
#       "isEnabled": true
#     },
#     {
#       "name": "size",
#       "isEnabled": true
#     },
#     {
#       "name": "contentType",
#       "isEnabled": true
#     },
#     {
#       "name": "keywords",
#       "isEnabled": true
#     }
#   ],
#   "ownershipBasedAccessControlForFeatures": {
#     "allowOthersToQuery": true,
#     "allowOthersToDelete": false,
#     "allowAnonymousToDelete": false,
#     "allowAnonymousToUpdate": false,
#     "allowOthersToUpdate": false
#   },
#   "id": 0,
#   "supportsValidateSql": true,
#   "geometryType": "esriGeometryPoint",
#   "drawingInfo": {
#     "renderer": {
#       "type": "simple",
#       "symbol": {
#         "url": "RedSphere.png",
#         "contentType": "image/png",
#         "height": 15,
#         "width": 15,
#         "type": "esriPMS",
#         "imageData": "..."
#       }
#     }
#   },
#   "hasStaticData": false,
#   "htmlPopupType": "esriServerHTMLPopupTypeNone",
#   "capabilities": "Create,Query,Editing,Extract,Sync",
#   "supportsTruncate": false
# }

# %%
# Get fields
for f in photos_layer.properties.fields:
    print(f['name'])
# Out:
# FID
# GlobalID
# CreationDate
# Creator
# EditDate
# Editor
# Name
# Description
# LocationName
# Hidden
# Vetted

# 789  Debris from destroyed mobile homes lay in the ...     0.0
# 790  Residents of Southwind Village Trailer Park wo...     0.0
# 791  boat dips into the canal as houses in Cudjoe K...     0.0
# 792  Water surrounds the homes in North Fort Myers,...     0.0
# 793  A gas station in Key West, Fla., shows signs o...     0.0
# 794  Sea Breeze RV and Mobile Home Park in Islamora...     0.0
# 795                     Crescent Beach Vacation Condos     0.0
# 796                                       Indian Pines     0.0
# 797                            Eagle Drive under water     0.0
# 798           devatation in Holiday Manor Neighborhood     0.0
# 799                        Destruction in Marco Island     0.0
# 800  drone capturedaerial view of everglades in the...     0.0
# 801  drone captured aerial view of everglades in th...     0.0
# 802  drone captured aerial view of everglades city ...     0.0
# 803  drone captured aerial view of Naples in the wa...     0.0
# 804  Damage in Marco Island ,drone captured aerial ...     0.0
# 805  Damage in Marco Island ,during Hurricane Irma,...     0.0
# 806  Damage in Marco Island ,during Hurricane Irma,...     0.0
# 807             flooded Citrus Park in Bonita Springs      0.0
# 808                                 McDonald's on US17     0.0
# 809                                    City Hall Annex     0.0
# 810                          Data center facade damage     0.0
# 811                                 Damage light poles     0.0
#
#                                                  SHAPE
# 0    {'x': -6885037.626084686, 'y': 2003587.8446435...
# 1    {'x': -6726048.607251563, 'y': 1939992.2371102...
# 2    {'x': -6996436.934498935, 'y': 2025673.660328603}
# 3    {'x': -6996436.833838484, 'y': 2025668.882815214}
# 4    {'x': -6985640.08370273, 'y': 1955293.0754573096}
# 5    {'x': -7018228.579044256, 'y': 2040592.0234558...
# 6    {'x': -7018699.145059968, 'y': 2042216.951406741}
# 7    {'x': -7018744.347794603, 'y': 2042214.402388763}
# 8    {'x': -7018722.551298191, 'y': 2042208.1321637...
# 9    {'x': -6996337.601179763, 'y': 2025573.2962169...
# 10   {'x': -7018394.254842275, 'y': 2049393.8809298...
# 11   {'x': -7018203.16227156, 'y': 2049355.6624156607}
# 12   {'x': -7018107.615986205, 'y': 2049336.5531585...
# 13   {'x': -6994381.1611290695, 'y': 2025419.007887...
# 14   {'x': -6994451.062925731, 'y': 2026114.5320603...
# 15    {'x': -9033057.302874591, 'y': 3087872.72312572}
# 16   {'x': -7020256.020892571, 'y': 2042217.0619626...
# 17   {'x': -7018109.908233158, 'y': 2048669.2368761...
# 18   {'x': -7195792.005018314, 'y': 2087453.5744528...
# 19   {'x': -7195524.475419316, 'y': 2087338.918910453}
# 20   {'x': -7190594.287094929, 'y': 2087977.4069946...
# 21    {'x': -6882188.34650901, 'y': 1995109.472789536}
# 22   {'x': -6878892.641191794, 'y': 1994371.5066085...
# 23    {'x': -7194977.325133968, 'y': 2084267.29464122}
# 24   {'x': -7359604.397478962, 'y': 2092377.2815187...
# 25   {'x': -7193568.114557412, 'y': 2087461.3624255...
# 26   {'x': -7193434.34975791, 'y': 2087475.6943683964}
# 27    {'x': -7193258.03316021, 'y': 2087058.815751061}
# 28   {'x': -6878892.641191794, 'y': 1994371.5066085...
# 29   {'x': -6878892.641191794, 'y': 1994371.5066085...
# ..                                                 ...
# 782  {'x': -9332257.751413256, 'y': 3547809.6422935...
# 783  {'x': -9169107.044719895, 'y': 2648002.944959397}
# 784  {'x': -9167291.562974423, 'y': 2648439.342864291}
# 785  {'x': -9281067.735780137, 'y': 4023181.292754301}
# 786  {'x': -9077037.906342642, 'y': 3662758.226785845}
# 787  {'x': -9105470.144613013, 'y': 3016349.0592807...
# 788  {'x': -9105470.144613013, 'y': 3016350.1829752...
# 789  {'x': -9105470.144613013, 'y': 3016349.0592807...
# 790  {'x': -9105470.144613013, 'y': 3016350.1829752...
# 791  {'x': -9071465.379760388, 'y': 2834670.3290707...
# 792  {'x': -9116948.29730871, 'y': 3083822.6366483667}
# 793  {'x': -9105165.709880814, 'y': 2822248.940342568}
# 794  {'x': -8968775.375893412, 'y': 2870867.933195648}
# 795  {'x': -9042894.080822352, 'y': 3467784.401377721}
# 796  {'x': -8948882.086017137, 'y': 3189769.4904170...
# 797  {'x': -8948246.869987419, 'y': 3190518.051874444}
# 798  {'x': -9103806.389483333, 'y': 3016688.677216805}
# 799  {'x': -9097544.196868528, 'y': 2993395.9036148...
# 800  {'x': -9059720.060286792, 'y': 2981373.111715925}
# 801  {'x': -9059720.060286792, 'y': 2981373.3209899...
# 802  {'x': -9059720.060286792, 'y': 2981373.3209899...
# 803  {'x': -9103803.702244056, 'y': 3016654.6388526...
# 804  {'x': -9097544.196868528, 'y': 2993395.9036148...
# 805  {'x': -9097544.196868528, 'y': 2993396.8312678...
# 806  {'x': -9097544.196868528, 'y': 2993396.8312678...
# 807   {'x': -9105821.91420392, 'y': 3040087.605747075}
# 808  {'x': -9098474.394902283, 'y': 3252229.070743589}
# 809  {'x': -9098246.499166964, 'y': 3252355.178676401}
# 810  {'x': -9098101.783828933, 'y': 3251979.660726295}
# 811  {'x': -9098211.557215689, 'y': 3251344.946912614}
#
# [812 rows x 12 columns]

# %%
layer_len = query.df.shape[0];
layer_len
# Out:
# 812

# %%
# Change directory to temp folder for storage of attachments
workfolder = r"C:\Users\Alberto Nieto\Documents\GitHub\GISMachineLearning\Attachments"
os.chdir(workfolder)

# %%
for oid in range(1, 182):
    print("Downloading photos for feature with object ID of {0}...".format(str(oid)))
    
    try:

        # Retrieve the attachment_id of the primary photo in this oid
        photos_list = photos_layer.attachments.get_list(oid)
        primary_photo_id = photos_list[-1]['id']  # Retrieve the last photo in the attachments list

        # Call the ArcGIS API for Python's download method on the attachments object
        photo_path = photos_layer.attachments.download(oid=oid, attachment_id=primary_photo_id, save_path=workfolder)

        # Rename the downloaded attachment based on oid
        os.rename(photo_path, os.path.join(workfolder, "Photo_{0}.jpeg".format(str(oid))))
        
    except IndexError as ex:
        print(ex)
        print("Could not download photo for feature OID {0}. Confirm this record has an attachment if needed.".format(str(oid)))
# Out:
# Downloading photos for feature with object ID of 1...
# Downloading photos for feature with object ID of 2...
# Downloading photos for feature with object ID of 3...
# Downloading photos for feature with object ID of 4...
# Downloading photos for feature with object ID of 5...
# Downloading photos for feature with object ID of 6...
# Downloading photos for feature with object ID of 7...
# Downloading photos for feature with object ID of 8...
# Downloading photos for feature with object ID of 9...
# Downloading photos for feature with object ID of 10...
# Downloading photos for feature with object ID of 11...
# Downloading photos for feature with object ID of 12...
# Downloading photos for feature with object ID of 13...
# Downloading photos for feature with object ID of 14...
# Downloading photos for feature with object ID of 15...
# Downloading photos for feature with object ID of 16...
# list index out of range
# Could not download photo for feature OID 16. Confirm this record has an attachment if needed.
# Downloading photos for feature with object ID of